# %%
import numpy as np
import pandas as pd
from pathlib import Path
import warnings

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
train_df
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0          13375    0.1797       483.34       MORTGAGE    223000.0
# 1          21000    0.1308       478.68       MORTGAGE    123000.0
# 2          20000    0.1240       448.95       MORTGAGE    197000.0
# 3           3000    0.1240       100.22           RENT     45000.0
# 4          30000    0.1612      1056.49       MORTGAGE    133000.0
# ...          ...       ...          ...            ...         ...
# 12175      19975    0.2565       801.09           RENT     28000.0
# 12176      15000    0.1774       540.34           RENT     50000.0
# 12177       3600    0.1862       131.28           RENT     60000.0
# 12178      15000    0.0881       475.68       MORTGAGE     62000.0
# 12179      15000    0.1774       540.34           RENT     54080.0
#
#       verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0            Not Verified          n  29.99            0               0  ...
# ...

# %%
test_df
# Out:
#       loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0       40000.0    0.1033       856.40           RENT    128700.0
# 1       24450.0    0.1430       572.72       MORTGAGE     44574.0
# 2       13500.0    0.1430       316.23            OWN     60000.0
# 3       10625.0    0.1774       268.31           RENT     60000.0
# 4        6375.0    0.1862       232.46           RENT     60000.0
# ...         ...       ...          ...            ...         ...
# 4697    30000.0    0.1240       673.42           RENT    140480.0
# 4698    24000.0    0.0756       747.22           RENT     50000.0
# 4699    10000.0    0.2305       387.36           RENT     33000.0
# 4700     8000.0    0.1862       205.86           RENT     38000.0
# 4701    30000.0    0.2055      1123.34           RENT    180000.0
#
#      verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Source Verified          n  12.47          0.0             1.0  ...
# ...

# %%
X_train = pd.get_dummies(train_df.drop(columns=['loan_status']))
y_train = train_df['loan_status']

# %%
X_train
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0          13375    0.1797       483.34    223000.0  29.99            0
# 1          21000    0.1308       478.68    123000.0  11.26            2
# 2          20000    0.1240       448.95    197000.0  11.28            0
# 3           3000    0.1240       100.22     45000.0  18.08            0
# 4          30000    0.1612      1056.49    133000.0  27.77            0
# ...          ...       ...          ...         ...    ...          ...
# 12175      19975    0.2565       801.09     28000.0  28.42            0
# 12176      15000    0.1774       540.34     50000.0  23.43            4
# 12177       3600    0.1862       131.28     60000.0  28.80            0
# 12178      15000    0.0881       475.68     62000.0  11.44            0
# 12179      15000    0.1774       540.34     54080.0  21.66            1
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# ...

# %%
X_test = pd.get_dummies(test_df.drop(columns=['target']))
y_test = test_df['target']

# %%
X_test
# Out:
#       loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0       40000.0    0.1033       856.40    128700.0  12.47          0.0
# 1       24450.0    0.1430       572.72     44574.0  15.05          0.0
# 2       13500.0    0.1430       316.23     60000.0  28.72          0.0
# 3       10625.0    0.1774       268.31     60000.0  15.70          0.0
# 4        6375.0    0.1862       232.46     60000.0  35.50          0.0
# ...         ...       ...          ...         ...    ...          ...
# 4697    30000.0    0.1240       673.42    140480.0  15.74          0.0
# 4698    24000.0    0.0756       747.22     50000.0  26.81          0.0
# 4699    10000.0    0.2305       387.36     33000.0  38.51          0.0
# 4700     8000.0    0.1862       205.86     38000.0  16.36          0.0
# 4701    30000.0    0.2055      1123.34    180000.0  12.06          0.0
#
#       inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0                1.0       8.0      0.0    38113.0  ...
# ...

# %%
# add missing dummy variables to testing set
for col in X_train.columns:
    if col not in X_test.columns:
        X_test[col] = 0

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',random_state=1)
classifier 
warnings.filterwarnings("ignore")

# %%
classifier.fit(X_train, y_train)
classifier.score(X_train, y_train)
# Out:
# 0.6509852216748768

# %%
classifier.score(X_test, y_test)
# Out:
# 0.5091450446618461

# %%
#Logistic Regression model score on the unscaled data 
print(f'Training Score: {classifier.score(X_train, y_train)}')
print(f"Testing Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Score: 0.6509852216748768
# Testing Score: 0.5091450446618461

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
classifier.score(X_test, y_test)
# Out:
# 0.6339855380689069

# %%
classifier.score(X_train, y_train)
# Out:
# 1.0

# %%
#Random Forest Classifier model score on the unscaled data
print(f'Training Score: {classifier.score(X_train, y_train)}')
print(f"Testing Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Score: 1.0
# Testing Score: 0.6339855380689069

# %% [markdown]
# The RandomForestClassifier model accuracy score is 63% accuracy where as LogisticRegression model accuracy score is only 50% .
# So the RandomForestClassifier model is more acurate.

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
from sklearn.linear_model import LogisticRegression
classifier2 = LogisticRegression()
classifier2.fit(X_train_scaled, y_train)
classifier2.score(X_test_scaled, y_test)

#Logistic Regression model score on the scaled data 
print(f'Training Score: {classifier2.score(X_train_scaled,y_train)}')
print(f'Testing Score: {classifier2.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 0.7078817733990148
# Testing Score: 0.7615908124202467

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled,y_train)

#Random Forest Classifier model score on the scaled data
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6401531263292216

# %%
In the LogisticRegression accuracy increases from 50% on the unscaled data  to 76% on the scaled data
The RandomForestClassifier accuracy doesnt show much change from 63% on the unscaled data to 64% scaled data. 
This shows that the LogisticRegression could be sensitive to how the data is scaled, while random forests are not.
